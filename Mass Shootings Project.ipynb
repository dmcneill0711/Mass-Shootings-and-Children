# %%
# Import Dependencies
import pandas as pd
from sqlalchemy import create_engine
import psycopg2

# %%
# Upload CSV Downloaded From GVA.org
children_killed = "Resources/Children_Killed.csv"
children_df = pd.read_csv(children_killed)
children_df
# Out:
#       Incident ID      Incident Date        State City Or County  \
# 0         2322582       June 6, 2022         Ohio      Cleveland
# 1         2322231       June 5, 2022   California   Baldwin Park
# 2         2321188       June 4, 2022     Michigan        Detroit
# 3         2317117       May 31, 2022     Michigan        Wyoming
# 4         2316814       May 30, 2022      Alabama         Mobile
# ...           ...                ...          ...            ...
# 1832       491046      July 17, 2013   California        Oakland
# 1833       490245       July 1, 2013        Texas     Fort Worth
# 1834       485811     April 24, 2013     Illinois     Manchester
# 1835       479363   January 19, 2013   New Mexico    Albuquerque
# 1836      1119336  December 14, 2012  Connecticut     Sandy Hook
#
#                           Address  # Killed  # Injured  Operations
# 0        Donald Ave and E 77th St         1          0         NaN
# 1         Merced Ave and Palm Ave         2          0         NaN
# 2     20200 block of Goulburn Ave         1          0         NaN
# 3          2118 Godfrey Avenue SW         4          0         NaN
# 4          1300 block of Duval St         1          0         NaN
# ...                           ...       ...        ...         ...
# 1832  3400 block of Wilson Avenue         1          3         NaN
# 1833     2900 block of Pate Drive         4          0         NaN
# 1834                  East Street         6          1         NaN
# 1835               2806 Long Lane         5          0         NaN
# 1836              12 Dickenson Dr        28          2         NaN
#
# [1837 rows x 8 columns]

# %%
# Drop Operations Column With All Null Values
children_df = children_df.drop(['Operations'], axis=1)

# Format The Date To mm/dd/yyyy
children_df['Incident Date'] = children_df['Incident Date'].str.strip().str.replace(' ','')
children_df['Incident Date'] = children_df['Incident Date'].str.strip().str.replace('January','01/')
children_df['Incident Date'] = children_df['Incident Date'].str.strip().str.replace('February','02/')
children_df['Incident Date'] = children_df['Incident Date'].str.strip().str.replace('March','03/')
children_df['Incident Date'] = children_df['Incident Date'].str.strip().str.replace('April','04/')
children_df['Incident Date'] = children_df['Incident Date'].str.strip().str.replace('May','05/')
children_df['Incident Date'] = children_df['Incident Date'].str.strip().str.replace('June','06/')
children_df['Incident Date'] = children_df['Incident Date'].str.strip().str.replace('July','07/')
children_df['Incident Date'] = children_df['Incident Date'].str.strip().str.replace('August','08/')
children_df['Incident Date'] = children_df['Incident Date'].str.strip().str.replace('September','09/')
children_df['Incident Date'] = children_df['Incident Date'].str.strip().str.replace('October','10/')
children_df['Incident Date'] = children_df['Incident Date'].str.strip().str.replace('November','11/')
children_df['Incident Date'] = children_df['Incident Date'].str.strip().str.replace('December','12/')
children_df['Incident Date'] = children_df['Incident Date'].str.strip().str.replace(',','/')

# Target Incident Date Column And Select Rows That Have 2022
Children_2022 = children_df.loc[children_df['Incident Date'].str.contains('2022')]

# Final DataFrame
Children_2022
# Out:
#      Incident ID Incident Date        State City Or County  \
# 0        2322582     06/6/2022         Ohio      Cleveland
# 1        2322231     06/5/2022   California   Baldwin Park
# 2        2321188     06/4/2022     Michigan        Detroit
# 3        2317117    05/31/2022     Michigan        Wyoming
# 4        2316814    05/30/2022      Alabama         Mobile
# ..           ...           ...          ...            ...
# 124      2205638     01/6/2022     Maryland        Clinton
# 125      2205490     01/6/2022      Alabama     Tuscaloosa
# 126      2210967     01/5/2022     Oklahoma         Lawton
# 127      2205965     01/5/2022  Mississippi     Starkville
# 128      2204367     01/4/2022   Washington         Auburn
#
#                          Address  # Killed  # Injured
# 0       Donald Ave and E 77th St         1          0
# 1        Merced Ave and Palm Ave         2          0
# 2    20200 block of Goulburn Ave         1          0
# 3         2118 Godfrey Avenue SW         4          0
# 4         1300 block of Duval St         1          0
# ..                           ...       ...        ...
# 124       8500 block of Wendy St         2          1
# 125   8700 block of Charolais Dr         3          0
# 126             8802 NW Cache Rd         2          0
# 127               Santa Anita Dr         1          0
# 128     2100 block of 66th St SE         3          0
#
# [129 rows x 7 columns]

# %%
# Upload 2022 Mass Shootings Table From Wikipedia Website
url = 'https://en.wikipedia.org/wiki/List_of_mass_shootings_in_the_United_States_in_2022'

tables = pd.read_html(url)

tables
# Out:
# [     2022 date            City           State    Dead Injured  Total  \
#  0       June 7   Baltimore (7)        Maryland       2       2      4
#  1       June 7      Portsmouth        Virginia       3       1      4
#  2       June 6  Salt Lake City            Utah       1       3      4
#  3       June 5         Andrews  South Carolina       0       4      4
#  4       June 5         Saginaw        Michigan       3       2      5
#  ..         ...             ...             ...     ...     ...    ...
#  282  January 1          Auburn         Georgia  1[n 3]       3      4
#  283  January 1         Kenosha       Wisconsin       1       3      4
#  284  January 1      South Bend         Indiana       0       4      4
#  285  January 1          Denver        Colorado       2       2      4
#  286  January 1        Columbia        Missouri       0       4      4
#
#                                             Description
#  0    Four men sitting in the side yard of a house i...
#  1    Three people were killed and another injured i...
#  2    Four people were shot, one of them fatally, at...
#  3    Four people were injured in a drive-by shootin...
#  4    Three people were killed and two were wounded ...
#  ..                                                 ...
#  282  After officers were dispatched to respond to a...
#  283  A man was killed, and three others wounded, in...
#  284  Four people were wounded at a shooting at a Ne...
#  285  Two adults were killed, and two wounded, in an...
#  286  Four adults were wounded in the early morning ...
#
#  [287 rows x 7 columns],
#             Month Mass shootings Total number dead (including the shooters)  \
#  0        January             41                                         59
#  1       February             43                                         40
#  2          March             52                                         47
#  3          April             66                                         75
#  4            May             67                                         87
#  5           June            NaN                                        NaN
#  6           July            NaN                                        NaN
#  7         August            NaN                                        NaN
#  8      September            NaN                                        NaN
#  9        October            NaN                                        NaN
#  10      November            NaN                                        NaN
#  11      December            NaN                                        NaN
#  12         Total            NaN                                        NaN
#  13  Source:[309]   Source:[309]                               Source:[309]
#
#     Total number wounded (including the shooters)  \
#  0                                            128
#  1                                            174
#  2                                            217
#  3                                            271
#  4                                            324
#  5                                            NaN
#  6                                            NaN
#  7                                            NaN
#  8                                            NaN
#  9                                            NaN
#  10                                           NaN
#  11                                           NaN
#  12                                           NaN
#  13                                  Source:[309]
#
#     Occurred at a school or university Occurred at a place of worship
#  0                                   0                              0
#  1                                   1                              1
#  2                                   0                              0
#  3                                   1                              0
#  4                                   1                              1
#  5                                 NaN                            NaN
#  6                                 NaN                            NaN
#  7                                 NaN                            NaN
#  8                                 NaN                            NaN
#  9                                 NaN                            NaN
#  10                                NaN                            NaN
#  11                                NaN                            NaN
#  12                                NaN                            NaN
#  13                       Source:[309]                   Source:[309]  ,
#    .mw-parser-output .navbar{display:inline;font-size:88%;font-weight:normal}.mw-parser-output .navbar-collapse{float:left;text-align:left}.mw-parser-output .navbar-boxtext{word-spacing:0}.mw-parser-output .navbar ul{display:inline-block;white-space:nowrap;line-height:inherit}.mw-parser-output .navbar-brackets::before{margin-right:-0.125em;content:"[ "}.mw-parser-output .navbar-brackets::after{margin-left:-0.125em;content:" ]"}.mw-parser-output .navbar li{word-spacing:-0.125em}.mw-parser-output .navbar a>span,.mw-parser-output .navbar a>abbr{text-decoration:inherit}.mw-parser-output .navbar-mini abbr{font-variant:small-caps;border-bottom:none;text-decoration:none;cursor:inherit}.mw-parser-output .navbar-ct-full{font-size:114%;margin:0 7em}.mw-parser-output .navbar-ct-mini{font-size:114%;margin:0 4em}vteMass shootings in the United States  \
#  0                                               List
#  1                           Related terms and topics
#
#    .mw-parser-output .navbar{display:inline;font-size:88%;font-weight:normal}.mw-parser-output .navbar-collapse{float:left;text-align:left}.mw-parser-output .navbar-boxtext{word-spacing:0}.mw-parser-output .navbar ul{display:inline-block;white-space:nowrap;line-height:inherit}.mw-parser-output .navbar-brackets::before{margin-right:-0.125em;content:"[ "}.mw-parser-output .navbar-brackets::after{margin-left:-0.125em;content:" ]"}.mw-parser-output .navbar li{word-spacing:-0.125em}.mw-parser-output .navbar a>span,.mw-parser-output .navbar a>abbr{text-decoration:inherit}.mw-parser-output .navbar-mini abbr{font-variant:small-caps;border-bottom:none;text-decoration:none;cursor:inherit}.mw-parser-output .navbar-ct-full{font-size:114%;margin:0 7em}.mw-parser-output .navbar-ct-mini{font-size:114%;margin:0 4em}vteMass shootings in the United States.1
#  0    20th century 2000–2009 2018 2019 2020 2021 2022
#  1  Active shooter Gun violence in the United Stat...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ]

# %%
# Select Relevant Table
Mass_Shootings = pd.DataFrame(tables[0])

# Rename Column
Mass_Shootings = Mass_Shootings.rename(columns = {'2022 date': 'Incident Date'})

# Format The Date To mm/dd/yyyy
Mass_Shootings['Incident Date'] = Mass_Shootings['Incident Date'].str.strip().str.replace(' ','')
Mass_Shootings['Incident Date'] = Mass_Shootings['Incident Date'].str.strip().str.replace('January','01/')
Mass_Shootings['Incident Date'] = Mass_Shootings['Incident Date'].str.strip().str.replace('February','02/')
Mass_Shootings['Incident Date'] = Mass_Shootings['Incident Date'].str.strip().str.replace('March','03/')
Mass_Shootings['Incident Date'] = Mass_Shootings['Incident Date'].str.strip().str.replace('April','04/')
Mass_Shootings['Incident Date'] = Mass_Shootings['Incident Date'].str.strip().str.replace('May','05/')
Mass_Shootings['Incident Date'] = Mass_Shootings['Incident Date'].str.strip().str.replace('June','06/')
Mass_Shootings['Incident Date'] = Mass_Shootings['Incident Date'].str.strip().str.replace('July','07/')
Mass_Shootings['Incident Date'] = Mass_Shootings['Incident Date'].str.strip().str.replace('August','08/')
Mass_Shootings['Incident Date'] = Mass_Shootings['Incident Date'].str.strip().str.replace('September','09/')
Mass_Shootings['Incident Date'] = Mass_Shootings['Incident Date'].str.strip().str.replace('October','10/')
Mass_Shootings['Incident Date'] = Mass_Shootings['Incident Date'].str.strip().str.replace('November','11/')
Mass_Shootings['Incident Date'] = Mass_Shootings['Incident Date'].str.strip().str.replace('December','12/')
Mass_Shootings['Incident Date'] = Mass_Shootings['Incident Date'].str.strip().str.replace(',','/')

# Add Year To End of Date Column To Match Format Of Children_2022 DataFrame
Mass_Shootings_2022['Incident Date'] = Mass_Shootings_2022['Incident Date'].astype(str) + '/2022'

#Final Dataframe
Mass_Shootings_2022
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [8], in <cell line: 24>()
#      21 Mass_Shootings['Incident Date'] = Mass_Shootings['Incident Date'].str.strip().str.replace(',','/')
#      23 # Add Year To End of Date Column To Match Format Of Children_2022 DataFrame
# ---> 24 Mass_Shootings_2022['Incident Date'] = Mass_Shootings_2022['Incident Date'].astype(str) + '/2022'
#      26 #Final Dataframe
#      27 Mass_Shootings_2022
#
# NameError: name 'Mass_Shootings_2022' is not defined

# %%
#Create Engine and connection to Database
engine = create_engine('postgresql://postgres:hermantucker12@localhost:5432/Mass_Shootings')
conn = engine.connect()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~/opt/anaconda3/envs/PythonData/lib/python3.9/site-packages/sqlalchemy/engine/base.py:3256, in Engine._wrap_pool_connect(self, fn, connection)
#    3255 try:
# -> 3256     return fn()
#    3257 except dialect.dbapi.Error as e:
#
# File ~/opt/anaconda3/envs/PythonData/lib/python3.9/site-packages/sqlalchemy/pool/base.py:310, in Pool.connect(self)
#     303 """Return a DBAPI connection from the pool.
#     304
#     305 The connection is instrumented such that when its
#    (...)
#     308
#     309 """
# --> 310 return _ConnectionFairy._checkout(self)
#
# File ~/opt/anaconda3/envs/PythonData/lib/python3.9/site-packages/sqlalchemy/pool/base.py:868, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#     867 if not fairy:
# --> 868     fairy = _ConnectionRecord.checkout(pool)
#     870     fairy._pool = pool
#
# File ~/opt/anaconda3/envs/PythonData/lib/python3.9/site-packages/sqlalchemy/pool/base.py:476, in _ConnectionRecord.checkout(cls, pool)
#     474 @classmethod
#     475 def checkout(cls, pool):
# --> 476     rec = pool._do_get()
#     477     try:
#
# File ~/opt/anaconda3/envs/PythonData/lib/python3.9/site-packages/sqlalchemy/pool/impl.py:146, in QueuePool._do_get(self)
#     145         with util.safe_reraise():
# --> 146             self._dec_overflow()
#     147 else:
#
# File ~/opt/anaconda3/envs/PythonData/lib/python3.9/site-packages/sqlalchemy/util/langhelpers.py:70, in safe_reraise.__exit__(self, type_, value, traceback)
#      69     if not self.warn_only:
# ---> 70         compat.raise_(
#      71             exc_value,
#      72             with_traceback=exc_tb,
#      73         )
#      74 else:
#
# File ~/opt/anaconda3/envs/PythonData/lib/python3.9/site-packages/sqlalchemy/util/compat.py:207, in raise_(***failed resolving arguments***)
#     206 try:
# --> 207     raise exception
#     208 finally:
#     209     # credit to
#     210     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     211     # as the __traceback__ object creates a cycle
#
# File ~/opt/anaconda3/envs/PythonData/lib/python3.9/site-packages/sqlalchemy/pool/impl.py:143, in QueuePool._do_get(self)
#     142 try:
# --> 143     return self._create_connection()
#     144 except:
#
# File ~/opt/anaconda3/envs/PythonData/lib/python3.9/site-packages/sqlalchemy/pool/base.py:256, in Pool._create_connection(self)
#     254 """Called by subclasses to create a new ConnectionRecord."""
# --> 256 return _ConnectionRecord(self)
#
# File ~/opt/anaconda3/envs/PythonData/lib/python3.9/site-packages/sqlalchemy/pool/base.py:371, in _ConnectionRecord.__init__(self, pool, connect)
#     370 if connect:
# --> 371     self.__connect()
#     372 self.finalize_callback = deque()
#
# File ~/opt/anaconda3/envs/PythonData/lib/python3.9/site-packages/sqlalchemy/pool/base.py:666, in _ConnectionRecord.__connect(self)
#     665     with util.safe_reraise():
# --> 666         pool.logger.debug("Error on connect(): %s", e)
#     667 else:
#     668     # in SQLAlchemy 1.4 the first_connect event is not used by
#     669     # the engine, so this will usually not be set
#
# File ~/opt/anaconda3/envs/PythonData/lib/python3.9/site-packages/sqlalchemy/util/langhelpers.py:70, in safe_reraise.__exit__(self, type_, value, traceback)
#      69     if not self.warn_only:
# ---> 70         compat.raise_(
#      71             exc_value,
#      72             with_traceback=exc_tb,
#      73         )
#      74 else:
#
# File ~/opt/anaconda3/envs/PythonData/lib/python3.9/site-packages/sqlalchemy/util/compat.py:207, in raise_(***failed resolving arguments***)
#     206 try:
# --> 207     raise exception
#     208 finally:
#     209     # credit to
#     210     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     211     # as the __traceback__ object creates a cycle
#
# File ~/opt/anaconda3/envs/PythonData/lib/python3.9/site-packages/sqlalchemy/pool/base.py:661, in _ConnectionRecord.__connect(self)
#     660 self.starttime = time.time()
# --> 661 self.dbapi_connection = connection = pool._invoke_creator(self)
#     662 pool.logger.debug("Created new connection %r", connection)
#
# File ~/opt/anaconda3/envs/PythonData/lib/python3.9/site-packages/sqlalchemy/engine/create.py:590, in create_engine.<locals>.connect(connection_record)
#     589             return connection
# --> 590 return dialect.connect(*cargs, **cparams)
#
# File ~/opt/anaconda3/envs/PythonData/lib/python3.9/site-packages/sqlalchemy/engine/default.py:597, in DefaultDialect.connect(self, *cargs, **cparams)
#     595 def connect(self, *cargs, **cparams):
#     596     # inherits the docstring from interfaces.Dialect.connect
# --> 597     return self.dbapi.connect(*cargs, **cparams)
#
# File ~/opt/anaconda3/envs/PythonData/lib/python3.9/site-packages/psycopg2/__init__.py:122, in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     121 dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122 conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123 if cursor_factory is not None:
#
# OperationalError: connection to server at "localhost" (::1), port 5432 failed: FATAL:  password authentication failed for user "postgres"
#
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# Input In [19], in <cell line: 3>()
#       1 #Create Engine and connection to Database
#       2 engine = create_engine('postgresql://postgres:hermantucker12@localhost:5432/Mass_Shootings')
# ----> 3 conn = engine.connect()
#
# File ~/opt/anaconda3/envs/PythonData/lib/python3.9/site-packages/sqlalchemy/engine/base.py:3210, in Engine.connect(self, close_with_result)
#    3195 def connect(self, close_with_result=False):
#    3196     """Return a new :class:`_engine.Connection` object.
#    3197
#    3198     The :class:`_engine.Connection` object is a facade that uses a DBAPI
#    (...)
#    3207
#    3208     """
# -> 3210     return self._connection_cls(self, close_with_result=close_with_result)
#
# File ~/opt/anaconda3/envs/PythonData/lib/python3.9/site-packages/sqlalchemy/engine/base.py:96, in Connection.__init__(self, engine, connection, close_with_result, _branch_from, _execution_options, _dispatch, _has_events, _allow_revalidate)
#      91     self._has_events = _branch_from._has_events
#      92 else:
#      93     self._dbapi_connection = (
#      94         connection
#      95         if connection is not None
# ---> 96         else engine.raw_connection()
#      97     )
#      99     self._transaction = self._nested_transaction = None
#     100     self.__savepoint_seq = 0
#
# File ~/opt/anaconda3/envs/PythonData/lib/python3.9/site-packages/sqlalchemy/engine/base.py:3289, in Engine.raw_connection(self, _connection)
#    3267 def raw_connection(self, _connection=None):
#    3268     """Return a "raw" DBAPI connection from the connection pool.
#    3269
#    3270     The returned object is a proxied version of the DBAPI
#    (...)
#    3287
#    3288     """
# -> 3289     return self._wrap_pool_connect(self.pool.connect, _connection)
#
# File ~/opt/anaconda3/envs/PythonData/lib/python3.9/site-packages/sqlalchemy/engine/base.py:3259, in Engine._wrap_pool_connect(self, fn, connection)
#    3257 except dialect.dbapi.Error as e:
#    3258     if connection is None:
# -> 3259         Connection._handle_dbapi_exception_noconnection(
#    3260             e, dialect, self
#    3261         )
#    3262     else:
#    3263         util.raise_(
#    3264             sys.exc_info()[1], with_traceback=sys.exc_info()[2]
#    3265         )
#
# File ~/opt/anaconda3/envs/PythonData/lib/python3.9/site-packages/sqlalchemy/engine/base.py:2106, in Connection._handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    2104     util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    2105 elif should_wrap:
# -> 2106     util.raise_(
#    2107         sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2108     )
#    2109 else:
#    2110     util.raise_(exc_info[1], with_traceback=exc_info[2])
#
# File ~/opt/anaconda3/envs/PythonData/lib/python3.9/site-packages/sqlalchemy/util/compat.py:207, in raise_(***failed resolving arguments***)
#     204     exception.__cause__ = replace_context
#     206 try:
# --> 207     raise exception
#     208 finally:
#     209     # credit to
#     210     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     211     # as the __traceback__ object creates a cycle
#     212     del exception, replace_context, from_, with_traceback
#
# File ~/opt/anaconda3/envs/PythonData/lib/python3.9/site-packages/sqlalchemy/engine/base.py:3256, in Engine._wrap_pool_connect(self, fn, connection)
#    3254 dialect = self.dialect
#    3255 try:
# -> 3256     return fn()
#    3257 except dialect.dbapi.Error as e:
#    3258     if connection is None:
#
# File ~/opt/anaconda3/envs/PythonData/lib/python3.9/site-packages/sqlalchemy/pool/base.py:310, in Pool.connect(self)
#     302 def connect(self):
#     303     """Return a DBAPI connection from the pool.
#     304
#     305     The connection is instrumented such that when its
#    (...)
#     308
#     309     """
# --> 310     return _ConnectionFairy._checkout(self)
#
# File ~/opt/anaconda3/envs/PythonData/lib/python3.9/site-packages/sqlalchemy/pool/base.py:868, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#     865 @classmethod
#     866 def _checkout(cls, pool, threadconns=None, fairy=None):
#     867     if not fairy:
# --> 868         fairy = _ConnectionRecord.checkout(pool)
#     870         fairy._pool = pool
#     871         fairy._counter = 0
#
# File ~/opt/anaconda3/envs/PythonData/lib/python3.9/site-packages/sqlalchemy/pool/base.py:476, in _ConnectionRecord.checkout(cls, pool)
#     474 @classmethod
#     475 def checkout(cls, pool):
# --> 476     rec = pool._do_get()
#     477     try:
#     478         dbapi_connection = rec.get_connection()
#
# File ~/opt/anaconda3/envs/PythonData/lib/python3.9/site-packages/sqlalchemy/pool/impl.py:146, in QueuePool._do_get(self)
#     144     except:
#     145         with util.safe_reraise():
# --> 146             self._dec_overflow()
#     147 else:
#     148     return self._do_get()
#
# File ~/opt/anaconda3/envs/PythonData/lib/python3.9/site-packages/sqlalchemy/util/langhelpers.py:70, in safe_reraise.__exit__(self, type_, value, traceback)
#      68     self._exc_info = None  # remove potential circular references
#      69     if not self.warn_only:
# ---> 70         compat.raise_(
#      71             exc_value,
#      72             with_traceback=exc_tb,
#      73         )
#      74 else:
#      75     if not compat.py3k and self._exc_info and self._exc_info[1]:
#      76         # emulate Py3K's behavior of telling us when an exception
#      77         # occurs in an exception handler.
#
# File ~/opt/anaconda3/envs/PythonData/lib/python3.9/site-packages/sqlalchemy/util/compat.py:207, in raise_(***failed resolving arguments***)
#     204     exception.__cause__ = replace_context
#     206 try:
# --> 207     raise exception
#     208 finally:
#     209     # credit to
#     210     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     211     # as the __traceback__ object creates a cycle
#     212     del exception, replace_context, from_, with_traceback
#
# File ~/opt/anaconda3/envs/PythonData/lib/python3.9/site-packages/sqlalchemy/pool/impl.py:143, in QueuePool._do_get(self)
#     141 if self._inc_overflow():
#     142     try:
# --> 143         return self._create_connection()
#     144     except:
#     145         with util.safe_reraise():
#
# File ~/opt/anaconda3/envs/PythonData/lib/python3.9/site-packages/sqlalchemy/pool/base.py:256, in Pool._create_connection(self)
#     253 def _create_connection(self):
#     254     """Called by subclasses to create a new ConnectionRecord."""
# --> 256     return _ConnectionRecord(self)
#
# File ~/opt/anaconda3/envs/PythonData/lib/python3.9/site-packages/sqlalchemy/pool/base.py:371, in _ConnectionRecord.__init__(self, pool, connect)
#     369 self.__pool = pool
#     370 if connect:
# --> 371     self.__connect()
#     372 self.finalize_callback = deque()
#
# File ~/opt/anaconda3/envs/PythonData/lib/python3.9/site-packages/sqlalchemy/pool/base.py:666, in _ConnectionRecord.__connect(self)
#     664 except Exception as e:
#     665     with util.safe_reraise():
# --> 666         pool.logger.debug("Error on connect(): %s", e)
#     667 else:
#     668     # in SQLAlchemy 1.4 the first_connect event is not used by
#     669     # the engine, so this will usually not be set
#     670     if pool.dispatch.first_connect:
#
# File ~/opt/anaconda3/envs/PythonData/lib/python3.9/site-packages/sqlalchemy/util/langhelpers.py:70, in safe_reraise.__exit__(self, type_, value, traceback)
#      68     self._exc_info = None  # remove potential circular references
#      69     if not self.warn_only:
# ---> 70         compat.raise_(
#      71             exc_value,
#      72             with_traceback=exc_tb,
#      73         )
#      74 else:
#      75     if not compat.py3k and self._exc_info and self._exc_info[1]:
#      76         # emulate Py3K's behavior of telling us when an exception
#      77         # occurs in an exception handler.
#
# File ~/opt/anaconda3/envs/PythonData/lib/python3.9/site-packages/sqlalchemy/util/compat.py:207, in raise_(***failed resolving arguments***)
#     204     exception.__cause__ = replace_context
#     206 try:
# --> 207     raise exception
#     208 finally:
#     209     # credit to
#     210     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     211     # as the __traceback__ object creates a cycle
#     212     del exception, replace_context, from_, with_traceback
#
# File ~/opt/anaconda3/envs/PythonData/lib/python3.9/site-packages/sqlalchemy/pool/base.py:661, in _ConnectionRecord.__connect(self)
#     659 try:
#     660     self.starttime = time.time()
# --> 661     self.dbapi_connection = connection = pool._invoke_creator(self)
#     662     pool.logger.debug("Created new connection %r", connection)
#     663     self.fresh = True
#
# File ~/opt/anaconda3/envs/PythonData/lib/python3.9/site-packages/sqlalchemy/engine/create.py:590, in create_engine.<locals>.connect(connection_record)
#     588         if connection is not None:
#     589             return connection
# --> 590 return dialect.connect(*cargs, **cparams)
#
# File ~/opt/anaconda3/envs/PythonData/lib/python3.9/site-packages/sqlalchemy/engine/default.py:597, in DefaultDialect.connect(self, *cargs, **cparams)
#     595 def connect(self, *cargs, **cparams):
#     596     # inherits the docstring from interfaces.Dialect.connect
# --> 597     return self.dbapi.connect(*cargs, **cparams)
#
# File ~/opt/anaconda3/envs/PythonData/lib/python3.9/site-packages/psycopg2/__init__.py:122, in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     119     kwasync['async_'] = kwargs.pop('async_')
#     121 dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122 conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123 if cursor_factory is not None:
#     124     conn.cursor_factory = cursor_factory
#
# OperationalError: (psycopg2.OperationalError) connection to server at "localhost" (::1), port 5432 failed: FATAL:  password authentication failed for user "postgres"
#
# (Background on this error at: https://sqlalche.me/e/14/e3q8)

# %%
#Verify tables
engine.table_names()

# %%
#Use pandas to load mass shooting csv into converted DataFrame into database
clean_mass_shooting_df.to_sql(name='mass_shootings', con=engine, if_exists='append', index=False)

# %%
#confirm data has been added by querying table
pd.read_sql_query('select * from accidental_deaths', con=engine).head()
